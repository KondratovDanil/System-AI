# %% [markdown]
# # Практическая работа №3
# ## Тема: «Визуализация данных»
# ### Выполнил студент : Кондратов Данил
# ### Вариант: 13

# %% [markdown]
# ### Задание 1. Загрузить  данные из файла Dataset_Variants.xlsx, где номер листа ваш вариант
# ### Задание 2. Отобразить данные вашего варианта

# %%
import pandas as pd

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

print(lab)
# Out:
#      X           Y
# 0    1   50.928708
# 1    2   79.075636
# 2    3   36.667603
# 3    4    4.811983
# 4    5   49.176538
# 5    6   90.408395
# 6    7   45.827807
# 7    8   26.280037
# 8    9   35.621741
# 9   10   62.838882
# 10  11   -4.363682
# 11  12   51.583601
# 12  13  106.048975
# 13  14   66.950594
# 14  15   30.993380
# 15  16   36.099738
# 16  17   42.729954
# 17  18   39.738825
# 18  19   78.839963
# 19  20   54.028777
# 20  21   47.900517
# 21  22   99.305299
# 22  23   83.774484
# 23  24   86.175379
# 24  25   64.822831
# 25  26   28.140352
# 26  27   42.584179
# 27  28   46.692338
# 28  29   34.905003
# 29  30   33.863603
# 30  31   30.330472
# 31  32   38.909167
# 32  33   38.991419
# 33  34   35.576579
# 34  35   51.577860
# 35  36   70.973573
# 36  37   12.003244
# 37  38   53.906734
# 38  39   68.975982
# 39  40   46.277069
# 40  41   42.185508
# 41  42   60.844474
# 42  43   53.541260
# 43  44   55.777906
# 44  45   57.788373
# 45  46   16.658663
# ...

# %% [markdown]
# ### Задание 3. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

plt.bar(lab['X'], lab['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 4. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

plt.scatter(lab['X'], lab['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 5. Отрицательные значение по Y заменить значением по модулю
# ### Задание 6. Отобразить изменённые данные вашего варианта

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

lab['Y'] = lab['Y'].abs()

plt.scatter(lab['X'], lab['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 7. Визуализировать изменённые данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

lab['Y'] = lab['Y'].abs()

plt.bar(lab['X'], lab['Y'], color='green')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 8. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, столбцы зеленого цвета)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

lab['Y'] = lab['Y'].abs()

plt.scatter(lab['X'], lab['Y'], color='green')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 9. Визуализировать изменённые данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

lab['Y'] = lab['Y'].abs()

plt.plot(lab['X'], lab['Y'], color='blue', linestyle='--', marker='o')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 10. Визуализировать изменённые данные вашего варианта в стиле Линейный график с маркером (подписать оси, цвет, стиль линии и тип маркера изменить на ваше усмотрение)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

lab['Y'] = lab['Y'].abs()

plt.plot(lab['X'], lab['Y'], color='red', linestyle='-', marker='o')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 11. Визуализировать изменённые данные вашего варианта в стиле Цветовое распределение

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variant13.xlsx')

lab['Y'] = lab['Y'].abs()

sns.heatmap(lab, cmap='viridis')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 12. Загрузить и данные из файла Dataset_Variants.xlsx c номером листа 10000, где номер столбца Y ваш вариант
# ### Задание 13. Отобразить данные вашего варианта

# %%
import pandas as pd

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx ')

print(data)
# Out:
#           X            Y
# 0         1  1001.309672
# 1         2   989.039850
# 2         3   941.263013
# 3         4  1001.654541
# 4         5  1005.730783
# ...     ...          ...
# 9995   9996  1019.826302
# 9996   9997  1000.739277
# 9997   9998   995.090889
# 9998   9999   989.830314
# 9999  10000   956.200327
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### Задание 14. Визуализировать данные в стиле Столбчатые диаграммы (подписать оси)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx')

plt.bar(data['X'], data['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx')

plt.figure(figsize=(10, 6))  

plt.bar(data['X'], data['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx')

plt.figure(figsize=(20, 6)) 

plt.bar(data['X'], data['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 15. Визуализировать данные в стиле Точечный график (подписать оси)

# %%
import matplotlib.pyplot as plt

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx')

plt.figure(figsize=(10, 6))

plt.scatter(data['X'], data['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %%
import matplotlib.pyplot as plt

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx')

plt.figure(figsize=(30, 6))

plt.scatter(data['X'], data['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 16. Визуализировать данные вашего варианта в стиле Столбчатые диаграммы (подписать оси, столбцы зеленого цвета)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx')

plt.figure(figsize=(10, 6))

plt.bar(data['X'], data['Y'], color='green')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 17. Визуализировать данные вашего варианта в стиле Точечный график (подписать оси, столбцы красного цвета)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('C:\\Users\\Данил\\Downloads\\Dataset_Variants13.xlsx')

plt.figure(figsize=(10, 6))

plt.scatter(data['X'], data['Y'], color='red')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 18. Визуализировать данные вашего варианта в стиле Линейный график (подписать оси, цвет, стиль линии изменить на ваше усмотрение)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.plot(data['X'], data['Y'], color='purple', linestyle='-', marker='o')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(data['X'], data['Y'], color='purple', linestyle='-', marker='o')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 19. Визуализировать данные вашего варианта в стиле Цветовое распределение

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 15))

lab['Y'] = lab['Y'].abs()

sns.heatmap(lab, cmap='viridis')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# ### Задание 20. Загрузить и данные из вашего скаченного DataSet
# ### Задание 21. Отобразить данные вашего скаченного DataSet

# %%
import pandas as pd

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

print(lab)
# Out:
#      X   Y
# 0   12  32
# 1   10  12
# 2    4  34
# 3   23  45
# 4   35  67
# 5    9  98
# 6   10  10
# 7   45  32
# 8   67  54
# 9   15  63
# 10  55  97
# 11   1  21
# 12  37  11
# 13  12  -6
# 14   5  -1
# 15  33  -9
# 16  89  34
# 17  72  99
# 18  32  23
# 19   8  88
# 20  43  45
# 21  12  23
# 22  26  65
# 23  85  -8
# 24  44  70
# 25  90  19
# 26  86  28
# 27  43  33
# 28  33  64
# 29  21  59
# 30  90  76
# 31  55  54
# 32  87  98
# 33  32  -4
# 34  56  33
# 35  76  80
# 36   8  50
# 37  14  51
# 38  34  23
# 39  52  56
# 40  80  -7
# 41  78  45
# 42  56  23
# 43  37  76
# 44  23  -2
# 45  56  66
# 46  34  86
# 47  87  77
# 48   9  21
# 49   1  99
# 50  99  -1

# %% [markdown]
# ### Задание 22. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

plt.bar(lab['X'], lab['Y'], color='skyblue')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Столбчатая диаграмма')

plt.show()

# %% [markdown]
# ### Задание 23. Визуализировать данные вашего скаченного DataSet в стиле Точечный график (подписать оси, заголовок)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

plt.scatter(lab['X'], lab['Y'], color='red')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Точечный график')

plt.show()

# %% [markdown]
# ### Задание 24. Визуализировать данные вашего скаченного DataSet в стиле Столбчатые диаграммы (подписать оси, заголовок, столбцы зеленого цвета)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

plt.bar(lab['X'], lab['Y'], color='green')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Столбчатая диаграмма')

plt.show()

# %% [markdown]
# ### Задание 25. Визуализировать изменённые данные вашего варианта в стиле Точечный график (подписать оси, заголовок, столбцы красного цвета)

# %%
import pandas as pd
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

lab['Y'] = lab['Y'].abs()

plt.scatter(lab['X'], lab['Y'], color='red')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Точечный график')

plt.show()

# %% [markdown]
# ### Задание 26. Визуализировать данные вашего скаченного DataSet в стиле Линейный график (подписать оси, заголовок, цвет, стиль линии изменить на ваше усмотрение)

# %%
import pandas as pd
import matplotlib.pyplot as plt

laba = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

lab['Y'] = lab['Y'].abs()

plt.plot(lab['X'], lab['Y'], color='blue', linestyle='--', marker='o')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Линейный график')

plt.show()

# %% [markdown]
# ### Задание 27. Визуализировать данные вашего скаченного DataSet в стиле Цветовое распределение

# %%
import pandas as pd
import seaborn as sns

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

lab['Y'] = lab['Y'].abs()

sns.heatmap(lab.corr(), cmap='coolwarm')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

lab = pd.read_excel('C:\\Users\\Данил\\Downloads\\MyDataSet.xlsx')

lab['Y'] = lab['Y'].abs()

sns.heatmap(lab, cmap='viridis')

plt.xlabel('X')
plt.ylabel('Y')

plt.show()
