# %% [markdown]
# # Практическая работа №2
# ## Тема: «Операции с данными»
# ### Выполнила студент: Кондратов Данил
# ### ВАРИАНТ: 13
# ### Задание 1. Создать Series s1 и s2 по картинке

# %%
import pandas as pd
import numpy as np

# %%
apples = pd.Series([3, 2, 0, 1])
apples
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# dtype: int64

# %%
oranges = pd.Series([0, 3, 7, 2])
oranges
# Out:
# 0    0
# 1    3
# 2    7
# 3    2
# dtype: int64

# %% [markdown]
# ### Задание 2. Создать DataFrame df1 по картинке

# %%
result = pd.concat([apples, oranges], axis=1)
result.columns = ['Apples', 'Oranges'] 
result
# Out:
#    Apples  Oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# ### Задание 3. Загрузить ваш DataSet
# ### Название DataSet: cinema_successful_orders
# #### Здесь представлен датасет реальных заказов в Тинькофф Афиша.
# #### В нём присутствует данные о номере заказа, дате создания, датах сеансов, id фильма, со скольки лет разрешён вход, оценки фильма, количество билетов и стоимости билетов.

# %%
cinema_successful_orders = pd.read_excel("C:\\Users\\Данил\\OneDrive\\Desktop\\cinema_successful_orders.xlsx", sheet_name = 'cinema_successful_orders')
cinema_successful_orders
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 4. Показать первые 10 записей вашего DataFrame

# %%
cinema_successful_orders.head(10)
# Out:
#    order_id creation_date session_date  movie_id movie_age_restriction  \
# 0   2441412    2020-03-07   2020-03-07     32452                   12+
# 1   2169133    2020-02-03   2020-02-04     32452                   12+
# 2   2187694    2020-02-06   2020-02-06     32452                   12+
# 3   2182225    2020-02-05   2020-02-05     32452                   12+
# 4   2209967    2020-02-08   2020-02-12     32452                   12+
# 5   2206635    2020-02-08   2020-02-08     32452                   12+
# 6   2305515    2020-02-19   2020-02-19     32452                   12+
# 7   2184412    2020-02-05   2020-02-05     32452                   12+
# 8   2222760    2020-02-10   2020-02-10     32452                   12+
# 9   2175826    2020-02-04   2020-02-04     32452                   12+
#
#    movie_rating  number_of_tickets  ticket_price
# 0           7.7                  2     31.645570
# 1           7.7                  4     47.468354
# ...

# %% [markdown]
# ### Задание 5. Показать последние 10 записей вашего DataFrame

# %%
cinema_successful_orders.tail(10)
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 15175   2616691    2020-09-18   2020-09-19     38649                   12+
# 15176   2643900    2020-09-26   2020-09-26     38649                   12+
# 15177   2587283    2020-09-11   2020-09-11     38649                   12+
# 15178   2581967    2020-09-09   2020-09-10     38649                   12+
# 15179   2633788    2020-09-22   2020-09-22     38649                   12+
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# 15175          0.00                  4     47.468354
# ...

# %% [markdown]
# ### Задание 6. Показать случайные 10 строк из вашего DataFrame

# %%
cinema_successful_orders.sample(10)
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 964     2328736    2020-02-22   2020-02-22     36253                    6+
# 1786    2006912    2020-01-07   2020-01-07     29861                    6+
# 215     2175782    2020-02-04   2020-02-05     32452                   12+
# 9593    2214498    2020-02-09   2020-02-09     35403                    6+
# 2853    2000803    2020-01-06   2020-01-07     29861                    6+
# 7634    1946841    2020-01-01   2020-01-01     32107                   12+
# 10812   2677081    2020-10-09   2020-10-10     39947                   12+
# 13418   2489884    2020-03-14   2020-03-15     39065                    6+
# 1581    2075296    2020-01-18   2020-01-18     32600                   18+
# 14814   2305062    2020-02-19   2020-02-24     33359                   18+
#
#        movie_rating  number_of_tickets  ticket_price
# 964            0.00                  2     36.392405
# ...

# %% [markdown]
# ### Задание 7. Показать типы данных для каждого столбца в DataFrame

# %%
cinema_successful_orders.dtypes
# Out:
# order_id                          int64
# creation_date            datetime64[ns]
# session_date             datetime64[ns]
# movie_id                          int64
# movie_age_restriction            object
# movie_rating                    float64
# number_of_tickets                 int64
# ticket_price                    float64
# dtype: object

# %% [markdown]
# ### Задание 8. Показать информацию о DataFrame, включая количество непропущенных значений, типы данных

# %%
cinema_successful_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15185 entries, 0 to 15184
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               15185 non-null  int64
#  1   creation_date          15185 non-null  datetime64[ns]
#  2   session_date           15185 non-null  datetime64[ns]
#  3   movie_id               15185 non-null  int64
#  4   movie_age_restriction  15065 non-null  object
#  5   movie_rating           15185 non-null  float64
#  6   number_of_tickets      15185 non-null  int64
#  7   ticket_price           15185 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(1)
# memory usage: 949.2+ KB

# %% [markdown]
# ### Задание 9. Показать статистический анализ числовых столбцов, включая среднее, стандартное отклонение, минимум и максимум в DataFrame

# %%
cinema_successful_orders.describe()
# Out:
#            order_id                  creation_date  \
# count  1.518500e+04                          15185
# mean   2.284239e+06  2020-04-04 01:42:13.631873536
# min    1.937847e+06            2020-01-01 00:00:00
# 25%    2.038402e+06            2020-01-12 00:00:00
# 50%    2.218477e+06            2020-02-09 00:00:00
# 75%    2.537188e+06            2020-08-22 00:00:00
# max    2.724942e+06            2020-10-30 00:00:00
# std    2.601127e+05                            NaN
#
#                         session_date      movie_id  movie_rating  \
# count                          15185  15185.000000  15185.000000
# mean   2020-04-04 12:51:55.179453440  35939.438261      3.375285
# min              2020-01-01 00:00:00     24.000000      0.000000
# 25%              2020-01-12 00:00:00  32107.000000      0.000000
# 50%              2020-02-10 00:00:00  32749.000000      4.100000
# 75%              2020-08-22 00:00:00  39947.000000      6.950000
# ...

# %% [markdown]
# ### Задание 10. Показать DataFrame с булевыми значениями, указывающими на пропущенные значения

# %%
cinema_successful_orders.isna()
# Out:
#        order_id  creation_date  session_date  movie_id  movie_age_restriction  \
# 0         False          False         False     False                  False
# 1         False          False         False     False                  False
# 2         False          False         False     False                  False
# 3         False          False         False     False                  False
# 4         False          False         False     False                  False
# ...         ...            ...           ...       ...                    ...
# 15180     False          False         False     False                  False
# 15181     False          False         False     False                  False
# 15182     False          False         False     False                  False
# 15183     False          False         False     False                  False
# 15184     False          False         False     False                  False
#
# ...

# %% [markdown]
# ### Задание 11. Заменить пропущенные значения значением value в DataFrame

# %%
cinema_successful_orders.fillna('value')
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 12. Заменить пропущенные значения значением среднего в DataFrame

# %%
cinema_successful_orders.fillna(50.119437)
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 13. Заменить пропущенные значения значением медианы в DataFrame

# %%
cinema_successful_orders.fillna(91.75)
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 14. Заменить пропущенные значения значением максимальным в DataFrame

# %%
cinema_successful_orders.fillna(100.000000)
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 15. Заменить пропущенные значения значением минимальным в DataFrame

# %%
cinema_successful_orders.fillna(0.000001)
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 16. Показать количество уникальных значений в каждом столбце в DataFrame

# %%
cinema_successful_orders.nunique()
# Out:
# order_id                 15185
# creation_date              195
# session_date               194
# movie_id                   346
# movie_age_restriction        5
# movie_rating                83
# number_of_tickets            6
# ticket_price               157
# dtype: int64

# %% [markdown]
# ### Задание 17. Подсчитать количество вхождений каждого уникального значения в столбце в DataFrame

# %%
cinema_successful_orders.value_counts()
# Out:
# order_id  creation_date  session_date  movie_id  movie_age_restriction  movie_rating  number_of_tickets  ticket_price
# 1937847   2020-01-01     2020-01-02    30595     12+                    0.00          2                  49.050633       1
# 2485571   2020-03-13     2020-03-13    38648     16+                    0.00          2                  23.734177       1
# 2484925   2020-03-13     2020-03-13    38648     16+                    0.00          2                  55.379747       1
# 2484931   2020-03-13     2020-03-14    39065     6+                     7.50          2                  39.556962       1
# 2484937   2020-03-13     2020-03-13    38648     16+                    0.00          2                  60.126582       1
#                                                                                                                         ..
# 2073139   2020-01-18     2020-01-18    32182     12+                    5.00          2                  39.556962       1
# ...

# %% [markdown]
# ### Задание 18. Удалить строки с пропущенными значениями в DataFrame

# %%
cinema_successful_orders.dropna()
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 19. Показать булевы значения, указывающие на дубликаты строк в DataFrame

# %%
cinema_successful_orders.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15180    False
# 15181    False
# 15182    False
# 15183    False
# 15184    False
# Length: 15185, dtype: bool

# %% [markdown]
# ### Задание 20. Удалить дубликаты строк из DataFrame

# %%
cinema_successful_orders.drop_duplicates()
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 21. Заменить определенные значения в DataFrame на указанные

# %%
cinema_successful_orders.replace(7.70, 9.0)
# Out:
#        order_id creation_date session_date  movie_id movie_age_restriction  \
# 0       2441412    2020-03-07   2020-03-07     32452                   12+
# 1       2169133    2020-02-03   2020-02-04     32452                   12+
# 2       2187694    2020-02-06   2020-02-06     32452                   12+
# 3       2182225    2020-02-05   2020-02-05     32452                   12+
# 4       2209967    2020-02-08   2020-02-12     32452                   12+
# ...         ...           ...          ...       ...                   ...
# 15180   2526705    2020-08-07   2020-08-07     47102                   12+
# 15181   2622933    2020-09-19   2020-09-19     38649                   12+
# 15182   2615604    2020-09-18   2020-09-18     38649                   12+
# 15183   2531379    2020-08-14   2020-08-14     47102                   12+
# 15184   2620301    2020-09-19   2020-09-19     38649                   12+
#
#        movie_rating  number_of_tickets  ticket_price
# ...

# %% [markdown]
# ### Задание 22. Сохранить DataFrame в формат Excel с именем Practice2_dataset.xlsx

# %%
cinema_successful_orders.to_excel('Practice2_dataset.xlsx')

# %% [markdown]
# ### Задание 23. Сохранить DataFrame в формат CSV с именем Practice2_ dataset.CSV

# %%
cinema_successful_orders.to_csv('Practice2_dataset.csv')

# %% [markdown]
# ### Задание 24. Сохранить DataFrame в формат JSON с именем Practice2_ dataset.json

# %%
cinema_successful_orders.to_json('Practice2_dataset.json')
